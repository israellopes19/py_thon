# %% [markdown]
# <a href="https://colab.research.google.com/github/israellopes19/py_thon/blob/main/Plotando_Grafico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
from random import randint

# %%
gastos = [ randint(1000, 2000) for i in range(12) ]

# %%
gastos
# Out:
# [1173, 1020, 1499, 1516, 1094, 1751, 1099, 1064, 1440, 1602, 1986, 1514]

# %%
[1890, 1659, 1544, 1663, 1792, 1983, 1552,1855,1585,1828, 1974,1564]
# Out:
# [1111, 1659, 1544, 1663, 1792, 1983, 1552, 1855, 1585, 1828, 1974, 1564]

# %%
meses = ["Janeiro", "Fevereiro", "Março","Abril","Maio","Junho","Julho","Agosto","Setembro","Outubro","Novembro","Dezembro"]

# %%
plt.plot(meses, gastos)
